# %% [markdown]
# <a href="https://colab.research.google.com/github/UdvekBathula/EDA_repo/blob/main/Generative_AI_model_using_Lang_Chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing a Gen-AI model using model **Gemini 2.5 Flash**

# %%
import google.generativeai as genai  ##Import Gen AI model

# %%
dir(genai)  ##Shows all the methods available under Gen-AI
# Out:
# ['ChatSession',
#  'GenerationConfig',
#  'GenerativeModel',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'annotations',
#  'caching',
#  'configure',
#  'create_tuned_model',
#  'delete_file',
#  'delete_tuned_model',
#  'embed_content',
#  'embed_content_async',
#  'get_base_model',
#  'get_file',
#  'get_model',
#  'get_operation',
#  'get_tuned_model',
#  'list_files',
#  'list_models',
#  'list_operations',
#  'list_tuned_models',
#  'protos',
#  'responder',
#  'string_utils',
#  'types',
#  'update_tuned_model',
#  'upload_file',
#  'utils']

# %%
genai.configure(api_key="AIzaSyBaoS50kxuMfK2OPrg5WBBQWKjJ2GQdKvA")

# %%
for i in list(genai.list_models()):     ##Prints the list of all the models available
  print(i.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# ...

# %%
model=genai.GenerativeModel("gemini-2.5-flash")    ##selects the model

# %%
dir(model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_async_client',
#  '_client',
#  '_generation_config',
#  '_get_tools_lib',
#  '_model_name',
#  '_prepare_request',
#  '_safety_settings',
#  '_system_instruction',
#  '_tool_config',
#  '_tools',
#  'cached_content',
#  'count_tokens',
#  'count_tokens_async',
#  'from_cached_content',
#  'generate_content',
#  'generate_content_async',
#  'model_name',
#  'start_chat']

# %%
response=model.generate_content('Describe about Prabhas')   ##generates response

# %%
print(response.text)
# Out:
# Prabhas, full name **Uppalapati Venkata Suryanarayana Prabhas Raju**, is an Indian actor predominantly known for his work in Telugu cinema. He rose to international fame and became a pan-Indian superstar with his starring role as Amarendra Baahubali and Mahendra Baahubali in S.S. Rajamouli's epic *Baahubali* film series.
#
# Here's a detailed description of Prabhas:
#
# 1.  **Early Life and Background:**
#     *   Born on October 23, 1979, in Madras (now Chennai), India.
#     *   He hails from a prominent film family; his father, U. Suryanarayana Raju, was a film producer, and his uncle, Krishnam Raju, was a veteran Telugu actor and politician (often referred to as "Rebel Star"). This lineage provided him with an entry point into the industry, but he built his career on his own merit.
#
# 2.  **Career Trajectory:**
# ...

# %% [markdown]
# Imprting a Gen-AI model using **LANG_CHAIN**

# %%
pip install langchain langchain_google_genai     ##import langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import langchain_google_genai as lagg  ##Import Gen-AI using langchain

# %%
dir(lagg)
# Out:
# ['ChatGoogleGenerativeAI',
#  'ComputerUse',
#  'Environment',
#  'GoogleGenerativeAI',
#  'GoogleGenerativeAIEmbeddings',
#  'HarmBlockThreshold',
#  'HarmCategory',
#  'MediaResolution',
#  'Modality',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_common',
#  '_compat',
#  '_enums',
#  '_function_utils',
#  '_image_utils',
#  'chat_models',
#  'create_context_cache',
#  'data',
#  'embeddings',
#  'llms',
#  'utils']

# %%
import os

# %%
from langchain_google_genai import ChatGoogleGenerativeAI ##Imports Gen-AI model 'Gemini 2.5 flash'

# %%
llm=ChatGoogleGenerativeAI(
    model='gemini-2.5-flash',
    api_key=api_key
    )

# %%
response=llm.invoke(' Write about Prabhas')   ##Generates response

# %%
print(response.content)
# Out:
# Uppalapati Venkata Suryanarayana Prabhas Raju, popularly known as **Prabhas**, is a name synonymous with monumental cinematic ambition and an unprecedented rise to pan-Indian and even global stardom. While he was a beloved "Darling" of Telugu cinema for over a decade, it was the magnum opus *Baahubali* that transformed him into a household name across India and beyond.
#
# **Early Life and Entry into Cinema:**
# Born on October 23, 1979, in Chennai, Prabhas hails from a prominent Telugu film family. His father, Uppalapati Suryanarayana Raju, was a well-known producer, and his uncle, Uppalapati Krishnam Raju, is a veteran actor and former Member of Parliament, often referred to as "Rebel Star." Growing up amidst the world of cinema, Prabhas naturally gravitated towards acting.
#
# ...
